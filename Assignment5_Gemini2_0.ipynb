# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheer9023/PIAIC_Assignments/blob/main/Assignment5_Gemini2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gemini-sdk
# Out:
# ERROR: Could not find a version that satisfies the requirement gemini-sdk (from versions: none)
# ERROR: No matching distribution found for gemini-sdk

# %%
# !pip install --upgrade --quiet google.genai


# !pip install gTTS --quiet


# !pip install playsound --quiet


# !pip install Ipython --quiet
# Out:
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7020 sha256=a1535399edf3aaaeb918d313e87b3a1b8e1eca6c3f028ee8d55397cad38789c2
#   Stored in directory: /root/.cache/pip/wheels/90/89/ed/2d643f4226fc8c7c9156fc28abd8051e2d2c0de37ae51ac45c
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0

# %%
import google.generativeai as genai
from google.colab import userdata
key: str = userdata.get('2.O_exp')
if(key):
  print("API Key found")
else:
  print("API Key not found")
# Out:
# API Key found

# %%
from google import genai
from google.genai import Client

client: Client = genai.Client(
    api_key=key,
)

model: str ="gemini-2.0-flash-exp"

# %%
video_file_name = "/content/shaheer.mp4"

# %%
import time

def upload_video(video_file_name):
  video_file = client.files.upload(path=video_file_name)
  while video_file.state == "PROCESSING":
      print('video is processing........')
      time.sleep(10)
      video_file = client.files.get(name=video_file.name or "")

  if video_file.state == "FAILED":
    raise ValueError(video_file.state)
  print(f'Video processing complete: ' + (video_file.uri or ""))

  return video_file

my_video = upload_video(video_file_name)
# Out:
# video is processing........
# Video processing complete: https://generativelanguage.googleapis.com/v1beta/files/6m82nk55x3mk

# %%
from google.genai.types import Content, Part
prompt = input("enter prompt : ")

video = my_video

response = client.models.generate_content(
    model=model,
    contents=[
        Content(
            role="user",
            parts=[
                Part.from_uri(
                    file_uri=video.uri or "",
                    mime_type=video.mime_type or ""),
                ]),
        prompt,
    ]
)
print(response.text)
# Out:
# enter prompt : tell me what i am saying
# Certainly! You are singing a religious song in Urdu or a related language. It appears to be a lament or a devotional song related to the figure of Hussain, and includes references to Muhammad. Some of the specific phrases I can identify are:
#
# * **La ilaha illallah** (There is no god but Allah)
# * **Muhammadur rasulullah** (Muhammad is the messenger of Allah)
# * **Darsgah Hussain** (the School of Hussain)
# * **Shabih e Mustafa** (Image of Mustafa)
#
# Based on the lyrics, it's likely a Shia Muslim devotional song.

# %%
# !pip install ipython  --quiet
from gtts import gTTS
from playsound import playsound
from IPython.display import Audio
tts = gTTS(text=response.text, lang='en')
with open('audio.mp3', 'wb') as f:
  for chunk in tts.stream():
    f.write(chunk)
display(Audio('audio.mp3'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
